# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("zomato_dataset_Engineered.csv")
df
# Out:
#            id delivery_person_id  delivery_person_age  \
# 0      0xcdcd      DEHRES17DEL01                 36.0
# 1      0xd987      KOCRES16DEL01                 21.0
# 2      0x2784     PUNERES13DEL03                 23.0
# 3      0xc8b6     LUDHRES15DEL02                 34.0
# 4      0xdb64      KNPRES14DEL02                 24.0
# ...       ...                ...                  ...
# 45488  0x7c09      JAPRES04DEL01                 30.0
# 45489  0xd641      AGRRES16DEL01                 21.0
# 45490  0x4f8d     CHENRES08DEL03                 30.0
# 45491  0x5eee    COIMBRES11DEL01                 20.0
# 45492  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        delivery_person_ratings  distance_km  order_date  time_ordered  \
# 0                          4.2         10.3  2022-02-12         21.55
# 1                          4.7          6.2  2022-02-13         14.55
# 2                          4.7         13.8  2022-03-04         17.30
# ...

# %% [markdown]
# # ANOVA TEST

# %%
from scipy.stats import f_oneway

low = df[df["road_traffic_density"] == "Low"]["time_taken_min"]
medium = df[df["road_traffic_density"] == "Medium"]["time_taken_min"]
high = df[df["road_traffic_density"] == "High"]["time_taken_min"]
jam = df[df["road_traffic_density"] == "Jam"]["time_taken_min"]

f_stat, p_value = f_oneway(low, medium, high, jam)

print("F-statistic:", f_stat)
print("p-value:", p_value)
if p_value < 0.05:
    print("Reject H0: Traffic level has a significant effect on delivery time.")
else:
    print("Fail to reject H0: No significant difference in delivery time.")
# Out:
# F-statistic: 3410.0930007529582
# p-value: 0.0
# Reject H0: Traffic level has a significant effect on delivery time.

# %% [markdown]
# # CHI SQUARE TEST

# %%
contingency_table = pd.crosstab(
    df["road_traffic_density"],
    df["type_of_vehicle"]
)

print(contingency_table)
# Out:
# type_of_vehicle       Bicycle  Electric_Scooter  Motorcycle  Scooter
# road_traffic_density
# High                        0               346        2611     1466
# Jam                         0              1166        8213     4760
# Low                         0              1216        9090     5170
# Medium                      0               893        6374     3678
# Unknown                    53               157         133      167

# %%
from scipy.stats import chi2_contingency

chi2, p_value, dof, expected = chi2_contingency(contingency_table)

print("Chi-square:", chi2)
print("p-value:", p_value)
print("Degrees of freedom:", dof)
if p_value < 0.05:
    print("Reject H0: Traffic level and vehicle type are associated.")
else:
    print("Fail to reject H0: No significant association.")
# Out:
# Chi-square: 5082.602614747344
# p-value: 0.0
# Degrees of freedom: 12
# Reject H0: Traffic level and vehicle type are associated.
